# %% [markdown]
# # Математическая логика

# %% [markdown]
# <img src='addition/les_3_task_1_2.JPG'/>

# %% [markdown]
# 3. ЕСЛИ сегодня НЕ светит солнце ИЛИ сегодня сыро, ТО я НЕ поеду на дачу

# %% [markdown]
# 4. я поеду на дачу, ЕСЛИ сегодня светит солнце ИЛИ сегодня НЕ сыро

# %% [markdown]
# 5. Существуют курсы на некоторых факультетах, где все студенты не сдают некоторые экзамены на "отлично".

# %% [markdown]
# 6. Есть студенты филосовского факультета, у которых нет друга, не способного решать некоторые логические задачи.

# %% [markdown]
# 7. Бывают самолёты на рейсе Вашингтон-Москва, в котороых отсутствуют все сотрудники силовых органов, у которых есть пуговицы одежды без вмонтированного микрофона.

# %% [markdown]
# 8. a = 0.(216)<br>
# 1000*a = 216 + a<br>
# a = 216/999 = 24/111 = 8/37

# %% [markdown]
# 9. a = 1.0(01)<br>
# 100*a = 100.1 + 0,0(01)<br>
# 100*a = 100.1 + a - 1<br>
# 99*a = 99.1<br>
# a = 991/990

# %% [markdown]
# 10. 1 = 1/2 + 1/3 + 1/6<br>
# 1 = 0.5(0) + 0.(3) + 0.1(6) = 0,(9)

# %% [markdown]
# 11. 1 = 1/2 + 1/5 + 1/10 + 1/12 + 1/15 + 1/20<br>
# 1 = 0.5(0) + 0.2(0) + 0.(1) + 0.08(3) + 0.0(6) + 0.05(0) = 0.(9)

# %% [markdown]
# 12. lim = 0
